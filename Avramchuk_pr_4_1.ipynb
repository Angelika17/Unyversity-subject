# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
a1 = pd.date_range(start="16/01/2023", end="16/03/2023", periods=5)
plt.rcParams["figure.figsize"]=[10,8]
plt.plot(a, [1,3,5,4,3])
plt.ylabel("mean temperature")


plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
a2=pd.date_range(start="16/12/2022", end="16/03/2023", periods=4)
plt.rcParams["figure.figsize"]=[10,8]
plt.plot(a2,[-4,-7,-3,0])
plt.xlabel("Date", fontsize="small", color="red")
plt.ylabel("temperature", fontsize="large", color="red")
plt.title("Mean temperature in Kyiv")
plt.grid()
plt.show()

# %%
a3=pd.date_range(start="30/05/2022", end="30/08/2022", periods=8)
plt.rcParams["figure.figsize"]=[10,8]
plt.plot(a3,[19,23,34,31,32,26,24,25])
plt.title("mean tempereture during summer", fontsize="large")
plt.ylabel("temperature",fontsize="smaller", color="red")
plt.xlabel("period",fontsize="small", color="red")
plt.text(a3[2],34,"The hotest period", color="red")
plt.grid()
plt.show()

# %%
labels=["Kyiv","Lviv","Odessa","Zytomir"]
a4=[50,96,38,35]
explode=[0,0,0,0]

plt.pie(a4,
        labels=labels,
        explode=explode,
        pctdistance=1.15,
        labeldistance=1.35
)
plt.title("Забруднення повітря")
plt.show()

# %%
plt.bar(['Israil',"China","India","Pakistan","South Korea"],
        [90,350,160,165,20],
        color=["blue","red","orange","green","black"],
        edgecolor="g"
        
)
plt.title("Кількість ядерних обеголовок по всьому світу",fontsize="large")
plt.show()

# %%
a5=plt.figure()
ax= a5.add_subplot(projection="3d")
x=[20,15,17]
z=[12,21,15]
y=[14,20,18]
s=[150,130,160]
ax.scatter(x,y,z,s=s)
